# %%
# %run "/Users/vitormeller4@gmail.com/secrets_config"

# %%
props = {"user": NEON_USER, "password": NEON_PASSWORD, "driver":"org.postgresql.Driver"}
df = spark.read.jdbc(JDBC_URL, "associado", properties=props)
display(df)
